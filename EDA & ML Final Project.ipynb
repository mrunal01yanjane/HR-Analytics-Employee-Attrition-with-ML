# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Education:
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# EnvironmentSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobInvolvement:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# PerformanceRating:
# 1 'Low'
# 2 'Good'
# 3 'Excellent'
# 4 'Outstanding'
#
# RelationshipSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# WorkLifeBalance:
# 1 'Bad'
# 2 'Good'
# 3 'Better'
# 4 'Best'

# %%
for i in df:
    print(i,":",df[i].unique())
    print("*******************************************************")
# Out:
# Age : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# *******************************************************
# Attrition : ['Yes' 'No']
# *******************************************************
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# *******************************************************
# DailyRate : [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.EmployeeCount.value_counts()
# Out:
# EmployeeCount
# 1    1470
# Name: count, dtype: int64

# %%
# Droping EmployeeCount column as it has only one type of value and EmployeeNumber as it is not useful for the analysis

df.drop(columns=["EmployeeCount","EmployeeNumber"],inplace = True)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
# Duplicated values in the dataset

df.duplicated().sum()
# Out:
# 0

# %%
# Null-Values

df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# Exploratory Data Analysis (EDA)
# -----

# %%
plt.figure(figsize = (10,6))
sns.histplot(df['Age'],color="red")
plt.title('Histogram of Age')
plt.show()

# %%
# Age vs MonothlyIncome
plt.figure(figsize = (10,6))
sns.scatterplot(x = df['Age'],y=df['MonthlyIncome'])
plt.show()

# %%
# Gender 
df['Gender'].value_counts().plot(kind="barh",edgecolor="black",color="g")
plt.xlabel("Count of Empolyee")
plt.ylabel("Gender")
plt.title("Gender wise count of Employee")
plt.show()
# There are more males than females in this dataset

# %%
df.groupby('Gender').Attrition.value_counts().plot(kind="barh",edgecolor="black",color="purple")
plt.show()

# %%
plt.figure(figsize=(8,6))
df["MaritalStatus"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                        wedgeprops={"edgecolor":"Black","linewidth":2,})  
plt.legend(title="Marital Status",loc="upper right")
plt.show()

# %%
sns.boxplot(data=df,x="Department",y="Age",palette="rainbow")
plt.show()

# %%
fig,axes=plt.subplots(2,3,figsize=(20,15))
sns.histplot(df['Age'],color="red",ax=axes[0,0])
sns.scatterplot(x = df['Age'],y=df['MonthlyIncome'],ax=axes[0,1])
df['Gender'].value_counts().plot(kind="barh",edgecolor="black",color="g",ax=axes[0,2])
df.groupby('Gender').Attrition.value_counts().plot(kind="barh",edgecolor="black",color="purple",ax=axes[1,0])
df["MaritalStatus"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                        wedgeprops={"edgecolor":"Black","linewidth":2,},ax=axes[1,1])
sns.boxplot(data=df,x="Department",y="Age",palette="rainbow",ax=axes[1,2])
plt.show()

# %% [markdown]
# MaritalStatus vs Attrition

# %%
df.groupby('Attrition').MaritalStatus.value_counts().plot(kind = "bar",edgecolor="black",color="royalblue")
plt.show()

# %%
df.groupby('JobSatisfaction').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="seagreen")
plt.show()

# %%
# Those who earn less are more likely to leave the company

df.groupby('Attrition')['MonthlyIncome'].mean().plot(kind = "bar",edgecolor="black",color="plum")
plt.show()

# %%
df.groupby('EnvironmentSatisfaction').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="tan")
plt.show()

# %%
df.groupby('WorkLifeBalance').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="darkred")
plt.show()

# %%
df.groupby('Department').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="gold")
plt.show()

# %%
fig,axes=plt.subplots(2,3,figsize=(20,15))
df.groupby('Attrition').MaritalStatus.value_counts().plot(kind = "bar",edgecolor="black",color="royalblue",ax=axes[0,0])
df.groupby('JobSatisfaction').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="seagreen",ax=axes[0,1])
df.groupby('Attrition')['MonthlyIncome'].mean().plot(kind = "bar",edgecolor="black",color="plum",ax=axes[0,2])
df.groupby('EnvironmentSatisfaction').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="tan",ax=axes[1,0])
df.groupby('WorkLifeBalance').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="darkred",ax=axes[1,1])
df.groupby('Department').Attrition.value_counts().sort_values(ascending = False).plot(kind = "bar",edgecolor="black",color="gold",ax=axes[1,2])
plt.show()

# %%
df.groupby('Attrition')['Age'].mean()
# Younger people are more likely to leave the company
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
sns.countplot(data=df,y="MaritalStatus",hue="Gender",palette="mako")
plt.show()

# %%
sns.countplot(data=df,x="BusinessTravel",hue="Gender",palette="mako")
plt.show()

# %%
sns.countplot(data=df,x="Department",hue="OverTime",palette="mako")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.kdeplot(data=df,x="Age",hue="JobRole")
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(15,5))
sns.countplot(data=df,y="MaritalStatus",hue="Gender",palette="mako",ax=axes[0])
sns.countplot(data=df,x="BusinessTravel",hue="Gender",palette="mako",ax=axes[1])
sns.countplot(data=df,x="Department",hue="OverTime",palette="mako",ax=axes[2])
plt.show()

# %% [markdown]
# Label Encoding
# -------------

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
column=['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']

for j in column:
    le=LabelEncoder()
    df[j]=le.fit_transform(df[j])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df.drop(columns=['Over18'] , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int32
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   int32
# ...

# %%
#HEATMAP

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='coolwarm')
plt.show()

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# MODEL BUILDING & DATA EVALUATION
# -------------

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df[df.columns] = scaler.fit_transform(df[df.columns])

# %%
df.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619        1.0             1.0   0.715820         1.0
# 1  0.738095        0.0             0.5   0.126700         0.5
# 2  0.452381        1.0             1.0   0.909807         0.5
# 3  0.357143        0.0             0.5   0.923407         0.5
# 4  0.214286        0.0             1.0   0.350036         0.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.000000       0.25             0.2                 0.333333
# 1          0.250000       0.00             0.2                 0.666667
# 2          0.035714       0.25             0.8                 1.000000
# 3          0.071429       0.75             0.2                 1.000000
# 4          0.035714       0.00             0.6                 0.000000
#
#    Gender  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0     0.0  ...                  0.000000            0.0          0.000000
# ...

# %%
#Features Target

X = df.drop('Attrition', axis=1)
Y = df['Attrition']

# %%
X
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.547619             1.0   0.715820         1.0          0.000000
# 1     0.738095             0.5   0.126700         0.5          0.250000
# 2     0.452381             1.0   0.909807         0.5          0.035714
# 3     0.357143             0.5   0.923407         0.5          0.071429
# 4     0.214286             1.0   0.350036         0.5          0.035714
# ...        ...             ...        ...         ...               ...
# 1465  0.428571             0.5   0.559771         0.5          0.785714
# 1466  0.500000             1.0   0.365784         0.5          0.178571
# 1467  0.214286             1.0   0.037938         0.5          0.107143
# 1468  0.738095             0.5   0.659270         1.0          0.035714
# 1469  0.380952             1.0   0.376521         0.5          0.250000
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
Y
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %%
#TRAINING TESTING SPLITING

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 99    0.619048             0.0   0.277022         0.5          0.785714
# 785   0.523810             1.0   0.994989         0.5          0.678571
# 918   0.785714             0.5   0.096636         1.0          0.285714
# 1335  0.500000             1.0   0.524696         0.5          0.642857
# 1182  0.428571             0.0   0.566929         0.5          0.000000
# ...        ...             ...        ...         ...               ...
# 715   0.357143             0.5   0.518969         0.5          0.000000
# 905   0.261905             1.0   0.423765         0.5          0.000000
# 1096  0.523810             1.0   0.569792         0.0          0.178571
# 235   0.595238             1.0   0.667144         1.0          0.535714
# 1061  0.142857             0.0   0.521117         1.0          0.428571
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
X_test
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1291  0.452381             1.0   0.191840         0.5          0.321429
# 1153  0.000000             0.5   0.316392         1.0          0.071429
# 720   0.285714             1.0   0.025770         0.5          0.750000
# 763   0.380952             1.0   0.881174         1.0          0.321429
# 976   0.904762             1.0   0.906943         0.5          0.785714
# ...        ...             ...        ...         ...               ...
# 1398  0.357143             0.5   0.859699         0.5          0.214286
# 351   0.333333             1.0   0.687187         0.5          0.035714
# 41    0.214286             1.0   0.814603         0.5          0.035714
# 1210  0.357143             1.0   0.118110         0.5          0.714286
# 1256  0.476190             0.5   0.352183         0.5          0.035714
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %% [markdown]
# LOGISTIC REGRESSION
# ----------

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
log.score(X_train,Y_train)
# Out:
# 0.8794946550048591

# %%
y_predict=log.predict(X_train)

# %%
y_predtest=log.predict(X_test)

# %%
log.score(X_test,Y_test)
# Out:
# 0.8594104308390023

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(Y_test,y_predtest))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.99      0.92       364
#          1.0       0.83      0.25      0.38        77
#
#     accuracy                           0.86       441
#    macro avg       0.84      0.62      0.65       441
# weighted avg       0.86      0.86      0.83       441

# %%
#CONFUSION MATRIX

tn,fp,fn,tp=confusion_matrix(Y_test,y_predtest).ravel()

# %%
print(tp,fp)  #Positive
print(fn,tn)  #Negative
# Out:
# 19 4
# 58 360

# %% [markdown]
# DECISION TREE
# -----

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.get_depth()
# Out:
# 15

# %%
dt.get_n_leaves()
# Out:
# 124

# %%
dt.score(X_train,Y_train)
# Out:
# 1.0

# %%
y_predict1=dt.predict(X_train)

# %%
y_predtest1=dt.predict(X_test)

# %%
dt.score(X_test,Y_test)
# Out:
# 0.7687074829931972

# %%
print(classification_report(Y_test,y_predtest1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.86      0.86       364
#          1.0       0.33      0.32      0.33        77
#
#     accuracy                           0.77       441
#    macro avg       0.60      0.59      0.59       441
# weighted avg       0.77      0.77      0.77       441

# %% [markdown]
# RANDOM FOREST
# ---------

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=100)

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_train,Y_train)
# Out:
# 1.0

# %%
y_predict2=rf.predict(X_train)

# %%
y_predtest2=rf.predict(X_test)

# %%
rf.score(X_test,Y_test)
# Out:
# 0.8390022675736961

# %%
print(classification_report(Y_test,y_predtest2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.99      0.91       364
#          1.0       0.71      0.13      0.22        77
#
#     accuracy                           0.84       441
#    macro avg       0.78      0.56      0.57       441
# weighted avg       0.82      0.84      0.79       441

# %% [markdown]
# ADAPTIVE BOOSTING
# ------------

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier(n_estimators=100)

# %%
ada.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
ada.score(X_train,Y_train)
# Out:
# 0.9203109815354713

# %%
y_predict3=ada.predict(X_train)

# %%
y_predtest3=ada.predict(X_test)

# %%
ada.score(X_test,Y_test)
# Out:
# 0.8639455782312925

# %%
print(classification_report(Y_test,y_predtest3))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92       364
#          1.0       0.66      0.45      0.54        77
#
#     accuracy                           0.86       441
#    macro avg       0.78      0.70      0.73       441
# weighted avg       0.85      0.86      0.85       441

# %% [markdown]
# EXTEME GRADIENT BOOSTING (XGBOOST
# ------------

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier(n_estimators=100)

# %%
xgb.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb.score(X_train,Y_train)
# Out:
# 1.0

# %%
y_predict4=xgb.predict(X_train)

# %%
y_predtest4=xgb.predict(X_test)

# %%
xgb.score(X_test,Y_test)
# Out:
# 0.8594104308390023

# %%
print(classification_report(Y_test,y_predtest4))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.98      0.92       364
#          1.0       0.74      0.30      0.43        77
#
#     accuracy                           0.86       441
#    macro avg       0.81      0.64      0.67       441
# weighted avg       0.85      0.86      0.83       441

# %%
print("Logistic Regression")
print("Accuracy:",log.score(X_test,Y_test))
print(classification_report(Y_test,y_predtest))
print("***********************************************************")
print("Decision Tree")
print("Accuracy:",dt.score(X_test,Y_test))
print(classification_report(Y_test,y_predtest1))
print("***********************************************************")
print("Random Forest")
print("Accuracy:",rf.score(X_test,Y_test))
print(classification_report(Y_test,y_predtest2))
print("***********************************************************")
print("Adaptive Boosting")
print("Accuracy:",ada.score(X_test,Y_test))
print(classification_report(Y_test,y_predtest3))
print("***********************************************************")
print("Extreme Gradient Boosting")
print("Accuracy:",xgb.score(X_test,Y_test))
print(classification_report(Y_test,y_predtest4))
# Out:
# Logistic Regression
# Accuracy: 0.8594104308390023
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.99      0.92       364
#          1.0       0.83      0.25      0.38        77
#
#     accuracy                           0.86       441
#    macro avg       0.84      0.62      0.65       441
# weighted avg       0.86      0.86      0.83       441
#
# ***********************************************************
# Decision Tree
# Accuracy: 0.7687074829931972
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.86      0.86       364
#          1.0       0.33      0.32      0.33        77
#
#     accuracy                           0.77       441
#    macro avg       0.60      0.59      0.59       441
# weighted avg       0.77      0.77      0.77       441
#
# ***********************************************************
# Random Forest
# Accuracy: 0.8390022675736961
# ...

# %% [markdown]
# Logistic Regression:
# -----------------------------
# The logistic regression model achieved precision of 86%, recall of 86%, f1-score of 83% (all weighted averages), and accuracy of 85.94%, on the test set.
# -----------
#
# Decision Tree:
# -----------------------------------
# The decision tree model achieved precision of 77%, recall of 77%, f1-score of 77%, and accuracy of 77.09%, on the test set.
# --------
#
# Random Forest:
# ----
# The random forest model acheievd precision of 84%, recall of 85%, f1-score of 80%, and accuracy of 84.80%, on the test set.
# ----------
#
# Adaptive Boosting:
# ---------
# The adaptive boosting model acheievd precision of 85%, recall of 86%, f1-score of 85%, and accuracy of 86.39%, on the test set.
# ---------
#
# Extreme Gradient Boostong(XGBoost):
# ---------
# The extreme gradient boosting model acheievd precision of 85%, recall of 86%, f1-score of 83%, and accuracy of 85.94%, on the test set.
# ---------

# %% [markdown]
# Summary
# ----
# The objective of this project was to develop a predictive model for employee attrition to help the HR department identify and retain valuable employees. We used an internal HR dataset of employee records, including features such as job role, education, performance retingd, and demographic information.
#
# Data preprocessing involved handling missing values, normalizing numerical features and encoding categorical variables. Exploratory Data Analysis (EDA) revealed that job satisfaction, work-life balance, and opportunities for career advancement were significant factors influencing employee attrition.
#
# Various models, including logistic regression, decision trees, random forest, adaptive boosting and extreme gradient boosting, were evaluated. The adaptive boosting model was selected due to its superior performance in predicting employee attrition. The final model achieved an accuracy of 86.39%, a precision of 85%, and a recall of 86% on the test dataset, indicating strong predictive performance.
#
# In conclusion, the project successfully developed a predictive model for employee attrition that can help the HR department proactively address retention issues. Future work could involve integrating real-time data to enhance predictive accuracy.
